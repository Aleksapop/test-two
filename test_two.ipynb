# %%
a = 5 # ovo je ceo broj int
b = 5.0 # ovo je broj sa decimalama float
c = "Petar" # ovo je string
d = True # ovo je bool
print(c + b)
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 c = "Petar" # ovo je string
#       4 d = True # ovo je bool
# ----> 5 print(c + b)
#       6 print(type(a))
#       7 print(type(b))
#
# TypeError: can only concatenate str (not "float") to str
