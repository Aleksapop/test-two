# %%
a = 5 # ovo je ceo broj int
b = 5.0 # ovo je broj sa decimalama float
c = "Petar" # ovo je string
d = True # ovo je bool
print(c + b)
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# 10.0
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
